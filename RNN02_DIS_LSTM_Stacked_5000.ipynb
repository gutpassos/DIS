# %% [markdown]
# # <font color='blue'>Deep Learning II</font>

# %% [markdown]
# # Redes Neurais Recorrentes LSTM - Long Short-Term Memory

# %% [markdown]
# Este Notebook está dividido nas seguintes etapas. Clique no título da etapa para acessá-la diretamente.
#
# * [Etapa 1](#etapa1): Conjunto de dados
# * [Etapa 2](#etapa2): Importar as Bibliotecas
# * [Etapa 3](#etapa3): Criar o Modelo
# * [Etapa 4](#etapa4): Testar o Modelo
# * [Etapa 5](#etapa5): Realizar as Previsões

# %% [markdown]
# # Prevendo Séries Temporais com Stacked LSTMs

# %% [markdown]
# Finalmente, vejamos um dos maiores benefícios das LSTMs, o fato de que elas podem ser treinadas com sucesso quando empilhadas em arquiteturas de redes profundas. As redes LSTM podem ser empilhadas em Keras da mesma maneira que outros tipos de camada podem ser empilhadas. Uma adição é que a camada LSTM anterior a cada camada LSTM subsequente, deve retornar a sequência. Isso pode ser feito configurando o parâmetro return_sequences = True na camada 1.

# %% [markdown]
# <a id = 'etapa1'></a>
# ## Etapa 1: Conjunto de dados

# %% [markdown]
# Previsão do distanciamento social em Minas Gerais.

# %% [markdown]
# Usaremos conjuntos de dados que mostram o distanciamento social em Minas Gerais. Os dados tem registros de 15/02/2020 a 29/01/2021.
#
# Será fornecido 1 dataset com 2 colunas, data e distanciamento social.

# %% [markdown]
# <a id='etapa2'></a>
# ## Etapa 2: Importar as Bibliotecas

# %%
import tensorflow as tf
tf.__version__
# Out:
# C:\Users\Guto\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# '2.0.0'

# %%
import keras as k
k.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %%
# Imports
import math
import numpy
import pandas as pd
import os
import io
import requests

from pandas.tseries.offsets import DateOffset

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import load_model

# Imports para visualização de dados
import matplotlib.pyplot as plt
import matplotlib as m

# Imports para formatação dos gráficos
plt.style.use('fivethirtyeight')
m.rcParams['axes.labelsize'] = 14
m.rcParams['xtick.labelsize'] = 12
m.rcParams['ytick.labelsize'] = 12
m.rcParams['text.color'] = 'k'
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from time import time

# %%
# Função Converte array em matriz
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# Função Carrega os dados
def carrega_dados():
# Carrega os dados
    dataframe = pd.read_csv("./data/AIH.csv")
    dataframe['Data'] = pd.to_datetime(dataframe.Data, format = '%d/%m/%Y')
    dataframe = dataframe.set_index('Data')

    # Converte dataset em array
    datasetfull = dataframe.values
    datasetfull = datasetfull.astype('float32')
    return datasetfull

# %%
# Função Split em treino e teste
def split_train_test(datasetfull):
    train_size = int(len(datasetfull) * 0.75)
    test_size = len(datasetfull) - train_size
    dataset, test = datasetfull[0:train_size,:], datasetfull[train_size:len(datasetfull),:]
    return dataset, test

# %%
# Função Split em treino e validação
def split_train_test_valid(train_set):
    train_size = int(len(dataset) * 0.67)
    valid_size = len(dataset) - train_size
    train, valid = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    return train, valid

# %%
# Define o PATH onde estão os dados
save_path = "./save"

# Random seed 
numpy.random.seed(7)

look_back = 10

# Cria o objeto scaler no intervalo [0, 1]
# usando a classe MinMaxScaler do scikit-learn
scaler = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# Clique no título da etapa para acessá-la diretamente.
#
# * [Etapa 1](#etapa1): Conjunto de dados
# * [Etapa 2](#etapa2): Importar as Bibliotecas
# * [Etapa 3](#etapa3): Criar o Modelo
# * [Etapa 4](#etapa4): Testar o Modelo
# * [Etapa 5](#etapa5): Realizar as Previsões

# %%
# Carrega os dados
datasetfull = carrega_dados()

# %%
# Split em treino e teste
dataset, test = split_train_test(datasetfull)

# %%
# Função Normaliza os dados
# As LSTMs são sensíveis à escala dos dados de entrada, especificamente quando funções de ativação sigmoide (padrão)
# ou tanh são usadas. Pode ser uma boa prática redimensionar os dados para o range de 0 a 1, 
# também chamado de normalização. 

dataset = scaler.fit_transform(dataset)

# %%
# Split em treino e validação
train, valid = split_train_test_valid(dataset)

# %%
dataset.shape
# Out:
# (262, 1)

# %%
train.shape
# Out:
# (175, 1)

# %%
valid.shape
# Out:
# (87, 1)

# %%
test.shape
# Out:
# (88, 1)

# %%
# Reshape em X=t e Y=t+1
trainX, trainY = create_dataset(train, look_back)
validX, validY = create_dataset(valid, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = numpy.reshape(validX, (validX.shape[0], validX.shape[1], 1))

# %%
# Cria o modelo LSTM
batch_size = 1

model = Sequential()
model.add(LSTM(200, batch_input_shape = (batch_size, look_back, 1), activation = 'relu', return_sequences = True))
model.add(LSTM(100, activation = 'relu', return_sequences = True))
model.add(LSTM(50,  activation = 'relu', return_sequences = True))
model.add(LSTM(25,  activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1))
    
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
# Cria o modelo LSTM
batch_size = 1

model = Sequential()
model.add(LSTM(200, batch_input_shape = (batch_size, look_back, 1), activation = 'relu', return_sequences = True))
model.add(LSTM(100, activation = 'relu', return_sequences = True))
model.add(LSTM(50,  activation = 'relu', return_sequences = True))
model.add(LSTM(25,  activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1))
    
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
model.summary()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 10, 200)              161600
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 10, 100)              120400
# _________________________________________________________________
# lstm_3 (LSTM)                (1, 10, 50)               30200
# _________________________________________________________________
# lstm_4 (LSTM)                (1, 25)                   7600
# _________________________________________________________________
# dense_1 (Dense)              (1, 20)                   520
# _________________________________________________________________
# dense_2 (Dense)              (1, 10)                   210
# _________________________________________________________________
# dense_3 (Dense)              (1, 1)                    11
# =================================================================
# Total params: 320,541
# Trainable params: 320,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Treinamento
start = time()

for i in range(200):
    model.fit(trainX, trainY, epochs = 1, batch_size = batch_size, verbose = 1, shuffle = False)
    model.reset_states()
    
print ('\nTempo gasto: %s segundos' % str(time() - start))

# %%
# Treinamento
start = time()

for i in range(5000):
    model.fit(trainX, trainY, epochs = 1, batch_size = batch_size, verbose = 1, shuffle = False)
    model.reset_states()
    
print ('\nTempo gasto: %s segundos' % str(time() - start))
# Out:
# Epoch 1/1
# 164/164 [==============================] - 11s 66ms/step - loss: 0.0346
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0279
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0290
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0298
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0277
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0305
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0311
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0302
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0304
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0304
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0305
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0303
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0303
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0301
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0301
# Epoch 1/1
# 164/164 [==============================] - 9s 57ms/step - loss: 0.0299
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0299
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0297
# Epoch 1/1
# 164/164 [==============================] - 9s 57ms/step - loss: 0.0297:
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0292
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0322
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0298
# Epoch 1/1
# 164/164 [==============================] - 9s 56ms/step - loss: 0.0353
# Epoch 1/1
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
# Epoch 1/1
# 164/164 [==============================] - 9s 54ms/step - loss: 0.0291: 0
# Epoch 1/1
# 164/164 [==============================] - 9s 53ms/step - loss: 0.0291
#
# Tempo gasto: 45699.80908560753 segundos

# %%
#trainX

# %%
#trainY

# %%
# Salvando a rede inteira no formato HDF5 (salvando todos os componentes da rede, incluindo os pesos)
model.save(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

# %% [markdown]
# ## Agora recarregamos o modelo para realizamos uma previsão.

# %%
# Carrega os dados
datasetfull = carrega_dados()

# Split em treino e teste
dataset, test = split_train_test(datasetfull)

dataset = scaler.fit_transform(dataset)

# Split em treino e validação
train, valid = split_train_test_valid(dataset)

# %%
# Reshape em X=t e Y=t+1
trainX, trainY = create_dataset(train, look_back)
validX, validY = create_dataset(valid, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = numpy.reshape(validX, (validX.shape[0], validX.shape[1], 1))

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

model.summary()

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 10, 200)              161600
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 10, 100)              120400
# _________________________________________________________________
# lstm_3 (LSTM)                (1, 10, 50)               30200
# _________________________________________________________________
# lstm_4 (LSTM)                (1, 25)                   7600
# _________________________________________________________________
# dense_1 (Dense)              (1, 20)                   520
# _________________________________________________________________
# dense_2 (Dense)              (1, 10)                   210
# _________________________________________________________________
# dense_3 (Dense)              (1, 1)                    11
# =================================================================
# Total params: 320,541
# Trainable params: 320,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Previsões
batch_size = 1
trainPredict = model.predict(trainX, batch_size = batch_size)
model.reset_states()
validPredict = model.predict(validX, batch_size = batch_size)

# %%
# Inverte as previsões por conta da normalização
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
validPredict = scaler.inverse_transform(validPredict)
validY = scaler.inverse_transform([validY])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Score em Treino: %.4f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
print('Score em Validação: %.4f RMSE' % (validScore))

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Score em Treino: %.4f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
print('Score em Validação: %.4f RMSE' % (validScore))
# Out:
# Score em Treino: 6.3807 RMSE
# Score em Validação: 5.7923 RMSE

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação usando LSTM Stacked") 
plt.plot(scaler.inverse_transform(dataset), label = 'Dados', color = 'green')
plt.plot(trainPredictPlot, color = 'blue', label = 'Treino')
plt.plot(validPredictPlot, color = 'red', label = 'Previsão')
plt.legend(loc = 'upper left') 
plt.show()

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação usando LSTM Stacked") 
plt.plot(scaler.inverse_transform(dataset), label = 'Dados', color = 'green')
plt.plot(trainPredictPlot, color = 'blue', label = 'Treino')
plt.plot(validPredictPlot, color = 'red', label = 'Previsão')
plt.legend(loc = 'upper left') 
plt.show()

# %%
# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação LSTM Stacked") 
plt.plot(validY[0], label = 'Dados', color = 'green') 
plt.plot(validPredict[:,0], label = 'Previsão', color = 'red') 
plt.legend(loc = 'best') 
plt.show()

# %%
# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação LSTM Stacked") 
plt.plot(validY[0], label = 'Dados', color = 'green') 
plt.plot(validPredict[:,0], label = 'Previsão', color = 'red') 
plt.legend(loc = 'best') 
plt.show()

# %% [markdown]
# <a id='etapa4'></a>
# ## Etapa 4: Testar o Modelo

# %% [markdown]
# ## Vamos fazer o Forecasting para os dados de teste.

# %%
# Carrega os dados
dataframe = pd.read_csv("./data/AIH.csv")
dataframe['Data'] = pd.to_datetime(dataframe.Data, format = '%d/%m/%Y')
dataframe = dataframe.set_index('Data')

# Refinamos os dados para o gráfico da série original
# A variável QT_INTER é nossa variável target 
target = dataframe['QT_INTER']
raw_values = target.values

datasetfull = dataframe.values
datasetfull = datasetfull.astype('float32')

# Split em treino e teste
train_size = int(len(datasetfull) * 0.75)
test_size = len(datasetfull) - train_size
dataset, test = datasetfull[0:train_size,:], datasetfull[train_size:len(datasetfull),:]

# Normaliza os dados
scaler = MinMaxScaler(feature_range = (0, 1))
dataset = scaler.fit_transform(dataset)

# Normaliza os dados de Teste
scalerTeste = MinMaxScaler(feature_range = (0, 1))
testScaler = scalerTeste.fit_transform(test)

# Split em treino e validação
train_size = int(len(dataset) * 0.67)
valid_size = len(dataset) - train_size
train, valid = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape em X=t e Y=t+1
trainX, trainY = create_dataset(train, look_back)
validX, validY = create_dataset(valid, look_back)
testX, testY = create_dataset(testScaler, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = numpy.reshape(validX, (validX.shape[0], validX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

model.summary()

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 10, 200)              161600
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 10, 100)              120400
# _________________________________________________________________
# lstm_3 (LSTM)                (1, 10, 50)               30200
# _________________________________________________________________
# lstm_4 (LSTM)                (1, 25)                   7600
# _________________________________________________________________
# dense_1 (Dense)              (1, 20)                   520
# _________________________________________________________________
# dense_2 (Dense)              (1, 10)                   210
# _________________________________________________________________
# dense_3 (Dense)              (1, 1)                    11
# =================================================================
# Total params: 320,541
# Trainable params: 320,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Previsões com dados de Teste
#model.reset_states()
trainPredict = model.predict(trainX, batch_size = batch_size)
model.reset_states()
validPredict = model.predict(validX, batch_size = batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size = batch_size)

# %%
# Inverte as previsões por conta da normalização
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
validPredict = scaler.inverse_transform(validPredict)
validY = scaler.inverse_transform([validY])
testPredict = scalerTeste.inverse_transform(testPredict)
testY = scalerTeste.inverse_transform([testY])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Score em Treino: %.4f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
print('Score em Validação: %.4f RMSE' % (validScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Score em Teste: %.4f RMSE' % (testScore))
# Out:
# Score em Treino: 6.3807 RMSE
# Score em Validação: 5.7923 RMSE
# Score em Teste: 5.2433 RMSE

# %%
# Plot do baseline e previsões
plt.figure(figsize = (20, 6))
plt.title("Previsão com os dados de Teste usando LSTM Time Steps") 
plt.plot(testY[0], label = 'Dados', color = 'green') 
plt.plot(testPredict[:,0], label = 'Previsão', color = 'purple') 
plt.legend(loc = 'best') 
plt.show()

# %%
# Plot do baseline e previsões
plt.figure(figsize = (20, 6))
plt.title("Previsão com os dados de Teste usando LSTM Time Steps") 
plt.plot(testY[0], label = 'Dados', color = 'green') 
plt.plot(testPredict[:,0], label = 'Previsão', color = 'purple') 
plt.legend(loc = 'best') 
plt.show()

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(datasetfull)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict               

# Ajusta as previsões em validação para o plot
testPredictPlot = numpy.empty_like(datasetfull)
testPredictPlot[:, :] = numpy.nan
#testPredictPlot[len(testPredict)+(look_back*2)+1:len(datasetfull)-1, :] = testPredict
testPredictPlot[(len(trainPredict) + len(validPredict))+(look_back*3)+2:len(datasetfull)-1, :] = testPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 6))
plt.title("Previsão com os dados de Treino e Validação usando LSTM Stacked") 
plt.plot(datasetfull, label = 'Dados',color = 'green')
plt.plot(trainPredictPlot, label = 'Treino', color = 'blue')
plt.plot(validPredictPlot, label = 'Validação', color = 'red')
plt.plot(testPredictPlot, label = 'Teste', color = 'purple')
plt.legend(loc = 'upper left') 
plt.show()

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(datasetfull)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict               

# Ajusta as previsões em validação para o plot
testPredictPlot = numpy.empty_like(datasetfull)
testPredictPlot[:, :] = numpy.nan
#testPredictPlot[len(testPredict)+(look_back*2)+1:len(datasetfull)-1, :] = testPredict
testPredictPlot[(len(trainPredict) + len(validPredict))+(look_back*3)+2:len(datasetfull)-1, :] = testPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 6))
plt.title("Previsão com os dados de Treino e Validação usando LSTM Stacked") 
plt.plot(datasetfull, label = 'Dados',color = 'green')
plt.plot(trainPredictPlot, label = 'Treino', color = 'blue')
plt.plot(validPredictPlot, label = 'Validação', color = 'red')
plt.plot(testPredictPlot, label = 'Teste', color = 'purple')
plt.legend(loc = 'upper left') 
plt.show()

# %% [markdown]
# <a id='etapa5'></a>
# ## Etapa 5: Realizar as Previsões

# %% [markdown]
# ## Vamos fazer o Forecasting para 77 dias de horizonte de previsão

# %%
# Carrega os dados
dataframe = pd.read_csv("./data/AIH.csv")
dataframe['Data'] = pd.to_datetime(dataframe.Data, format = '%d/%m/%Y')
dataframe = dataframe.set_index('Data')

# Refinamos os dados para o gráfico da série original
# A variável QT_INTER é nossa variável target 
target = dataframe['QT_INTER']
raw_values = target.values

datasetfull = dataframe.values
datasetfull = datasetfull.astype('float32')

# Split em treino e teste
train_size = int(len(datasetfull) * 0.75)
test_size = len(datasetfull) - train_size
dataset, test = datasetfull[0:train_size,:], datasetfull[train_size:len(datasetfull),:]

# Normaliza os dados
scaler = MinMaxScaler(feature_range = (0, 1))
dataset = scaler.fit_transform(dataset)

# Normaliza os dados de Teste
scalerTeste = MinMaxScaler(feature_range = (0, 1))
testScaler = scalerTeste.fit_transform(test)

# Split em treino e validação
train_size = int(len(dataset) * 0.67)
valid_size = len(dataset) - train_size
train, valid = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape em X=t e Y=t+1
trainX1, trainY = create_dataset(train, look_back)
validX1, validY = create_dataset(valid, look_back)
testX1, testY = create_dataset(testScaler, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX1, (trainX1.shape[0], trainX1.shape[1], 1))
validX = numpy.reshape(validX1, (validX1.shape[0], validX1.shape[1], 1))
testX = numpy.reshape(testX1, (testX1.shape[0], testX1.shape[1], 1))

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 10, 200)              161600
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 10, 100)              120400
# _________________________________________________________________
# lstm_3 (LSTM)                (1, 10, 50)               30200
# _________________________________________________________________
# lstm_4 (LSTM)                (1, 25)                   7600
# _________________________________________________________________
# dense_1 (Dense)              (1, 20)                   520
# _________________________________________________________________
# dense_2 (Dense)              (1, 10)                   210
# _________________________________________________________________
# dense_3 (Dense)              (1, 1)                    11
# =================================================================
# Total params: 320,541
# Trainable params: 320,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_DIS_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 10, 200)              161600
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 10, 100)              120400
# _________________________________________________________________
# lstm_3 (LSTM)                (1, 10, 50)               30200
# _________________________________________________________________
# lstm_4 (LSTM)                (1, 25)                   7600
# _________________________________________________________________
# dense_1 (Dense)              (1, 20)                   520
# _________________________________________________________________
# dense_2 (Dense)              (1, 10)                   210
# _________________________________________________________________
# dense_3 (Dense)              (1, 1)                    11
# =================================================================
# Total params: 320,541
# Trainable params: 320,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fazemos uma previsão em uma etapa
def forecast_lstm(model, X):
    X = X.reshape(1, look_back, 1)
    yhat = model.predict(X)
    yhat1 = scaler.inverse_transform(yhat)
    return yhat1[0,0]

# %%
# Validação direta nos dados de teste

# Lista para as previsões
previsoes_lstm = list()

# Previsões

for i in range(len(testX1)):   
   
    # Ajusta o shape dos dados de teste
    X, y = testX1[i], testY[i]
    
    # Previsão

    yhat = forecast_lstm(model, X)
    
    # Armazena o forecast
    previsoes_lstm.append(yhat)
    expected = raw_values[len(testX1) + i ]
    
    print('Mês = %d, Valor Previsto = %f, Valor Esperado = %f' % (i + 1, yhat, expected))
# Out:
# Mês = 1, Valor Previsto = 40.023743, Valor Esperado = 42.500000
# Mês = 2, Valor Previsto = 40.023743, Valor Esperado = 48.100000
# Mês = 3, Valor Previsto = 40.023743, Valor Esperado = 40.400000
# Mês = 4, Valor Previsto = 40.023743, Valor Esperado = 39.700000
# Mês = 5, Valor Previsto = 40.023743, Valor Esperado = 39.500000
# Mês = 6, Valor Previsto = 40.023743, Valor Esperado = 40.300000
# Mês = 7, Valor Previsto = 40.023743, Valor Esperado = 37.800000
# Mês = 8, Valor Previsto = 40.023743, Valor Esperado = 40.000000
# Mês = 9, Valor Previsto = 40.023743, Valor Esperado = 43.400000
# Mês = 10, Valor Previsto = 40.023743, Valor Esperado = 39.400000
# Mês = 11, Valor Previsto = 40.023743, Valor Esperado = 39.600000
# Mês = 12, Valor Previsto = 40.023743, Valor Esperado = 39.300000
# Mês = 13, Valor Previsto = 40.023743, Valor Esperado = 39.100000
# Mês = 14, Valor Previsto = 40.023743, Valor Esperado = 38.300000
# Mês = 15, Valor Previsto = 40.023743, Valor Esperado = 43.200000
# Mês = 16, Valor Previsto = 40.023743, Valor Esperado = 48.900000
# Mês = 17, Valor Previsto = 40.023743, Valor Esperado = 38.900000
# Mês = 18, Valor Previsto = 40.023743, Valor Esperado = 38.600000
# Mês = 19, Valor Previsto = 40.023743, Valor Esperado = 37.600000
# Mês = 20, Valor Previsto = 40.023743, Valor Esperado = 38.200000
# Mês = 21, Valor Previsto = 40.023743, Valor Esperado = 36.800000
# Mês = 22, Valor Previsto = 40.023743, Valor Esperado = 41.800000
# Mês = 23, Valor Previsto = 40.023743, Valor Esperado = 51.900000
# Mês = 24, Valor Previsto = 40.023743, Valor Esperado = 39.000000
# Mês = 25, Valor Previsto = 40.023743, Valor Esperado = 37.900000
# Mês = 26, Valor Previsto = 40.023743, Valor Esperado = 37.700000
# Mês = 27, Valor Previsto = 40.023743, Valor Esperado = 38.100000
# Mês = 28, Valor Previsto = 40.023743, Valor Esperado = 36.100000
# Mês = 29, Valor Previsto = 40.023743, Valor Esperado = 40.100000
# Mês = 30, Valor Previsto = 40.023743, Valor Esperado = 47.400000
# Mês = 31, Valor Previsto = 40.023743, Valor Esperado = 37.800000
# Mês = 32, Valor Previsto = 40.023743, Valor Esperado = 37.400000
# Mês = 33, Valor Previsto = 40.023743, Valor Esperado = 36.800000
# Mês = 34, Valor Previsto = 40.023743, Valor Esperado = 36.100000
# Mês = 35, Valor Previsto = 40.023743, Valor Esperado = 36.500000
# Mês = 36, Valor Previsto = 40.023743, Valor Esperado = 38.700000
# Mês = 37, Valor Previsto = 40.023743, Valor Esperado = 46.700000
# Mês = 38, Valor Previsto = 40.023743, Valor Esperado = 35.700000
# Mês = 39, Valor Previsto = 40.023743, Valor Esperado = 35.100000
# Mês = 40, Valor Previsto = 40.023743, Valor Esperado = 36.300000
# Mês = 41, Valor Previsto = 40.023743, Valor Esperado = 43.300000
# Mês = 42, Valor Previsto = 40.023743, Valor Esperado = 35.400000
# Mês = 43, Valor Previsto = 40.023743, Valor Esperado = 39.100000
# Mês = 44, Valor Previsto = 40.023743, Valor Esperado = 46.400000
# Mês = 45, Valor Previsto = 40.023743, Valor Esperado = 36.200000
# Mês = 46, Valor Previsto = 40.023743, Valor Esperado = 36.800000
# Mês = 47, Valor Previsto = 40.023743, Valor Esperado = 35.600000
# Mês = 48, Valor Previsto = 40.023743, Valor Esperado = 36.400000
# Mês = 49, Valor Previsto = 40.023743, Valor Esperado = 33.200000
# Mês = 50, Valor Previsto = 40.023743, Valor Esperado = 38.700000
# Mês = 51, Valor Previsto = 40.023743, Valor Esperado = 46.500000
# Mês = 52, Valor Previsto = 40.023743, Valor Esperado = 36.500000
# Mês = 53, Valor Previsto = 40.023743, Valor Esperado = 36.600000
# Mês = 54, Valor Previsto = 40.023743, Valor Esperado = 36.600000
# Mês = 55, Valor Previsto = 40.023743, Valor Esperado = 36.400000
# Mês = 56, Valor Previsto = 40.023743, Valor Esperado = 35.400000
# Mês = 57, Valor Previsto = 40.023743, Valor Esperado = 40.600000
# Mês = 58, Valor Previsto = 40.023743, Valor Esperado = 48.100000
# Mês = 59, Valor Previsto = 40.023743, Valor Esperado = 39.000000
# Mês = 60, Valor Previsto = 40.023743, Valor Esperado = 38.200000
# Mês = 61, Valor Previsto = 40.023743, Valor Esperado = 37.800000
# Mês = 62, Valor Previsto = 40.023743, Valor Esperado = 37.500000
# Mês = 63, Valor Previsto = 40.023743, Valor Esperado = 36.200000
# Mês = 64, Valor Previsto = 40.023743, Valor Esperado = 40.300000
# Mês = 65, Valor Previsto = 40.023743, Valor Esperado = 47.500000
# Mês = 66, Valor Previsto = 40.023743, Valor Esperado = 38.100000
# Mês = 67, Valor Previsto = 40.023743, Valor Esperado = 37.100000
# Mês = 68, Valor Previsto = 40.023743, Valor Esperado = 37.100000
# Mês = 69, Valor Previsto = 40.023743, Valor Esperado = 37.200000
# Mês = 70, Valor Previsto = 40.023743, Valor Esperado = 36.200000
# Mês = 71, Valor Previsto = 40.023743, Valor Esperado = 40.400000
# Mês = 72, Valor Previsto = 40.023743, Valor Esperado = 47.200000
# Mês = 73, Valor Previsto = 40.023743, Valor Esperado = 38.400000
# Mês = 74, Valor Previsto = 40.023743, Valor Esperado = 39.100000
# Mês = 75, Valor Previsto = 40.023743, Valor Esperado = 37.600000
# Mês = 76, Valor Previsto = 40.023743, Valor Esperado = 37.800000
# Mês = 77, Valor Previsto = 40.023743, Valor Esperado = 33.500000

# %%
previsoes_lstm
# Out:
# [40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743,
#  40.023743]

# %%
# Última data da série
target.index[-1]
# Out:
# Timestamp('2021-01-29 00:00:00')

# %%
# Cria sequência de datas a partir da última data da nossa série original
datas_para_prever_forecasting = [target.index[-1] + DateOffset(days = x) for x in range(0, 78)]

# %%
# Objetos do tipo pd.Series dão mais trabalho para manipular. Vamos converter a série original em dataframe.
df_original = pandas.DataFrame(target)

# %%
# Vamos agora criar um novo dataframe 
# O índice (data) será a sequência de datas futuras
# O nome da coluna de dados extraímos da série original
# ATENÇÃO: Não estamos extraindo os dados da série original, somente o nome da coluna
data_futuras = pandas.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# Visualiza os dados
# Entendeu por que os valores NaN? São datas futuras, e precisamos agora incluir nossas previsões.
data_futuras
# Out:
#            QT_INTER
# 2021-01-30      NaN
# 2021-01-31      NaN
# 2021-02-01      NaN
# 2021-02-02      NaN
# 2021-02-03      NaN
# ...             ...
# 2021-04-12      NaN
# 2021-04-13      NaN
# 2021-04-14      NaN
# 2021-04-15      NaN
# 2021-04-16      NaN
#
# [77 rows x 1 columns]

# %%
# Usamos as datas futuras para extrair as previsões do nosso modelo
df_predict = pandas.DataFrame(testPredict,
                          index = data_futuras.index, columns = ['Prediction'])

# %%
df_predict
# Out:
#             Prediction
# 2021-01-30    40.19553
# 2021-01-31    40.19553
# 2021-02-01    40.19553
# 2021-02-02    40.19553
# 2021-02-03    40.19553
# ...                ...
# 2021-04-12    40.19553
# 2021-04-13    40.19553
# 2021-04-14    40.19553
# 2021-04-15    40.19553
# 2021-04-16    40.19553
#
# [77 rows x 1 columns]

# %%
# Concatenamos a série original com os valores de forecasting de 12 meses além da série
df_forecasting = pandas.concat([df_original, df_predict], axis = 1)

# %%
# Visualiza o dataframe
df_forecasting
# Out:
#             QT_INTER  Prediction
# 2020-02-15      31.6         NaN
# 2020-02-16      38.9         NaN
# 2020-02-17      24.0         NaN
# 2020-02-18      26.5         NaN
# 2020-02-19      27.8         NaN
# ...              ...         ...
# 2021-04-12       NaN    40.19553
# 2021-04-13       NaN    40.19553
# 2021-04-14       NaN    40.19553
# 2021-04-15       NaN    40.19553
# 2021-04-16       NaN    40.19553
#
# [427 rows x 2 columns]

# %%
df_forecasting.to_csv(r'./data/AIHForecastingStacked.csv', index = False)

# %%
# Plot
plt.figure(figsize = (18, 6))

# Série original
plt.plot(target.index[0:261], target.values[0:261], label = 'Valores Observados', color = 'Blue')
plt.plot(target.index[261:], target.values[261:], label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(df_forecasting.index, df_forecasting['Prediction'], label = 'Forecasting',  color = 'Red')

plt.title('Forecasting Com Modelo LSTM Sem_early stoppProfundo Em Horizonte de 77 dias de Previsão')
plt.xlabel('Data')
plt.ylabel('Distanciamento Social')
plt.legend()
plt.show()

# %%
# Plot
plt.figure(figsize = (18, 6))

# Série original
plt.plot(target.index[0:261], target.values[0:261], label = 'Valores Observados', color = 'Blue')
plt.plot(target.index[261:], target.values[261:], label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(df_forecasting.index, df_forecasting['Prediction'], label = 'Forecasting',  color = 'Red')

plt.title('Forecasting Com Modelo LSTM Sem_early stoppProfundo Em Horizonte de 77 dias de Previsão')
plt.xlabel('Data')
plt.ylabel('Distanciamento Social')
plt.legend()
plt.show()

# %% [markdown]
# Todas as aulas deste curso podem ser encontradas na timeline da Comunidade no portal da DSA: www.datascienceacademy.com.br

# %% [markdown]
# # Fim
